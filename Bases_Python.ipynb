# %% [markdown]
# <center> <font size=5><b> <span> Episode 3 : </span> </b>  Maitriser les prérequis de python pour la datascience</font></center>

# %% [markdown]
# #### **1. Bases de Python et introduction aux types de données**

# %% [markdown]
# ### **Commentaires**

# %%
#Ceci est un commentaire sur la ligne

# %% [markdown]
# ### **Variables**</br>
# Une variable peut être considérée comme un conteneur de stockage de données.</br>
# La syntaxe d'attribution de valeurs à une variable est la suivante : **Nom de la variable = valeur ou information**.

# %%
# Exemple
x = 4

# %%
x
# Out:
# 4

# %% [markdown]
# ### **Les opérateurs**</br>
# Les opérateurs effectuent des ajouts simples, des comparaisons, etc. sur des variables et des valeurs.

# %%
  #Opérateur arithmétique (+, -, *, /)
  x = 2
  y = 3
  x + y # addition
# Out:
# 5

# %%
x * y # multiplication
# Out:
# 6

# %%
#Opérateur de comparaison ( >, <, ==, != …)
x == y
# Out:
# False

# %%
x > y
# Out:
# False

# %% [markdown]
# ### **Entrée et sortie**
# Fonction d'impression (print)
#
# Fonction d'entrée (input)

# %%
# Exemple d'utilisation
nom = "Merveil"
prenom = "HOUENAGNON"

nom
# Out:
# 'Merveil'

# %%
print("Je m'appelle", nom, prenom)
# Out:
# Je m'appelle Merveil HOUENAGNON

# %%
name = input("What is your name? ")
print("Hello, " + name + "!")
# Out:
# What is your name? Kiwi
# Hello, Kiwi!

# %% [markdown]
# ### **Types de données en Python**
#
# En Python, il existe des types de données de base comme **int, float, string, etc**.
#
# Vous pouvez utiliser les types intégrés comme **list, set, etc.**, que nous aborderons dans cette session.

# %%
x = 7
type(x)
# Out:
# int

# %%
x=4.4
type(x)
# Out:
# float

# %%
a = '55'
type(a)
# Out:
# str

# %%
a = False
type(a)
# Out:
# bool

# %% [markdown]
# ### **Liste en python**
#
#
#
# *   Une liste est une structure de données ordonnée qui peut contenir des éléments de différents types.
#
# *   Les éléments dans une liste sont indexés, commençant par 0 pour le premier élément.
#
# *   Les listes sont modifiables, ce qui signifie que vous pouvez ajouter, supprimer ou modifier des éléments.

# %%
# List (Liste)
person= ["ISSA", "Pauline", 15,  13.5]
print("Affichage de person :", person)
# Out:
# Affichage de person : ['ISSA', 'Pauline', 15, 13.5]

# %%
# Accès aux éléments de la liste
premier_element = person[0]
dernier_element = person[3]
print("Premier element de person :", premier_element)
print("Dernier element de person :", dernier_element)
# Out:
# Premier element de person : ISSA
# Dernier element de person : 13.5

# %%
# Modification d'un élément de la liste
person[1] = "kiwi"
print("Liste mise à jour :", person)
# Out:
# Liste mise à jour : ['ISSA', 'kiwi', 15, 13.5]

# %%
# Ajout d'un élément à la fin de la liste
person.append("beninois")
print("Liste après ajout :", person)
# Out:
# Liste après ajout : ['ISSA', 'kiwi', 15, 13.5, 'beninois']

# %%
# Suppression d'un élément de la liste
person.remove(13.5)
print("Liste après suppression :", person)
# Out:
# Liste après suppression : ['ISSA', 'kiwi', 15, 'beninois']

# %% [markdown]
# ### **Set (Ensemble) :**
#
#
# *   Un ensemble est une collection non ordonnée d'éléments uniques.
#
# *   Les ensembles sont utiles pour effectuer des opérations telles que l'union, l'intersection, et la différence entre des ensembles.
#
# *   Les ensembles n'ont pas d'ordre spécifique et ne permettent pas d'indexation.

# %%
# Set (Ensemble)
legumes = {"carotte", "brocoli", "poivron", "haricot"}
print("Ensemble de légumes :", legumes)
# Out:
# Ensemble de légumes : {'poivron', 'brocoli', 'carotte', 'haricot'}

# %%
# Ajout d'un élément à l'ensemble
legumes.add("tomate")
print("Ensemble après ajout :", legumes)
# Out:
# Ensemble après ajout : {'poivron', 'carotte', 'haricot', 'brocoli', 'tomate'}

# %%
# Suppression d'un élément de l'ensemble
legumes.remove("brocoli")
print("Ensemble après suppression :", legumes)
# Out:
# Ensemble après suppression : {'poivron', 'carotte', 'haricot', 'tomate'}

# %% [markdown]
# ### **Tuple (Tuple) :**
#
#
# *   Un tuple est une collection ordonnée et immuable d'éléments.
#
# *   Les tuples sont similaires aux listes, mais une fois créés, leurs éléments ne peuvent pas être modifiés.
#
# *   Les tuples sont souvent utilisés pour représenter des collections de données immuables.

# %%
# Tuple (Tuple)
couleurs = ("rouge", "vert", "bleu")
print("Tuple de couleurs :", couleurs)
# Out:
# Tuple de couleurs : ('rouge', 'vert', 'bleu')

# %%
# Accès aux éléments du tuple
premiere_couleur = couleurs[0]
print("Première couleur :", premiere_couleur)
# Out:
# Première couleur : rouge

# %%
# Les tuples sont immuables, on ne peut pas modifier leurs éléments
couleurs[1] = "jaune"  # Cette ligne provoquerait une erreur
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-846f015eb694> in <cell line: 2>()
#       1 # Les tuples sont immuables, on ne peut pas modifier leurs éléments
# ----> 2 couleurs[1] = "jaune"  # Cette ligne provoquerait une erreur
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ### **Dictionary (Dictionnaire) :**
#
#
# *   Un dictionnaire est une structure de données qui associe des paires clé-valeur.
#
# *   Chaque élément dans un dictionnaire a une clé unique et une valeur correspondante.
#
# *   Les dictionnaires permettent un accès rapide aux valeurs en utilisant leurs clés, mais ils ne sont pas ordonnés.

# %%
# Dictionary (Dictionnaire)
personne = {"nom": "Dupont", "prenom": "Jean", "age": 30}
print("Dictionnaire de personne :", personne)
# Out:
# Dictionnaire de personne : {'nom': 'Dupont', 'prenom': 'Jean', 'age': 30}

# %%
# Accès aux valeurs du dictionnaire
nom_personne = personne["nom"]
print("Nom de la personne :", nom_personne)
# Out:
# Nom de la personne : Dupont

# %%
# Modification de la valeur d'une clé dans le dictionnaire
personne["age"] = 31
print("Dictionnaire mis à jour :", personne)
# Out:
# Dictionnaire mis à jour : {'nom': 'Dupont', 'prenom': 'Jean', 'age': 31}

# %%
# Ajout d'une nouvelle paire clé-valeur
personne["ville"] = "Paris"
print("Dictionnaire après ajout :", personne)
# Out:
# Dictionnaire après ajout : {'nom': 'Dupont', 'prenom': 'Jean', 'age': 31, 'ville': 'Paris'}

# %% [markdown]
# ### **2- Structure de contrôle :**
#
# **Définition :** Les structures de contrôle permettent d'exécuter des blocs de code conditionnellement.
#
# **Types de structures de contrôle :** if, else, elif.

# %% [markdown]
# **La Structure de Contrôle if**

# %%
if condition:
    # Bloc de code exécuté si la condition est vraie

# %%
#Exemple
age = 18
if age >= 18:
    print("Vous êtes majeur.")
# Out:
# Vous êtes majeur.

# %% [markdown]
# **La Structure de Contrôle if-else**

# %%
if condition:
    # Bloc de code exécuté si la condition est vraie
else:
    # Bloc de code exécuté si la condition est fausse

# %%
#Exemple
age = 16
if age >= 18:
    print("Vous êtes majeur.")
else:
    print("Vous êtes mineur.")
# Out:
# Vous êtes mineur.

# %% [markdown]
# **La Structure de Contrôle elif**

# %%
if condition1:
    # Bloc de code exécuté si condition1 est vraie
elif condition2:
    # Bloc de code exécuté si condition2 est vraie
elif condition3:
    # Bloc de code exécuté si condition3 est vraie
else:
    # Bloc de code exécuté si aucune des conditions n'est vraie

# %%
#Exemple
score = 75
if score >= 90:
    print("Excellent!")
elif score >= 70:
    print("Bien joué!")
else:
    print("Peut faire mieux.")
# Out:
# Bien joué!

# %% [markdown]
# ### **3- Boucles :**
#
# **Définition :**  Les boucles permettent d'exécuter un bloc de code plusieurs fois.
#
# **Types de structures de contrôle :** for et while

# %% [markdown]
# **La Boucle for**

# %%
for variable in sequence:
    # Bloc de code exécuté à chaque itération

# %%
fruits = ["pomme", "banane", "orange"]
for fruit in fruits:
    print("je suis", fruit)
# Out:
# je suis pomme
# je suis banane
# je suis orange

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# **La Boucle while**

# %%
while condition:
    # Bloc de code exécuté tant que la condition est vraie

# %%
count = 1
while count <= 10:
    print("J'ai compté", count)
    count += 1
# Out:
# J'ai compté 1
# J'ai compté 2
# J'ai compté 3
# J'ai compté 4
# J'ai compté 5
# J'ai compté 6
# J'ai compté 7
# J'ai compté 8
# J'ai compté 9
# J'ai compté 10

# %% [markdown]
# ### **4- Fonctions en Python :**
#
#
# *   Lorsqu’une tâche doit être réalisée plusieurs fois par un programme avec seulement des paramètres différents, on peut l’isoler au sein d’une fonction
#
# *   Cette approche est également intéressante si la personne qui définit la fonction est différente de celle qui l’utilise
#
# *   Par exemple, nous avons déjà utilisé la fonction print() qui avait été définie par quelqu’un d’autre.

# %%
# Définition d’une fonction - def
def nom_fonction(liste de paramètres):
      bloc d'instructions

# %%
# Fonction qui calcule l'addition de deux nombres
def somme(a, b):
  return a - b

# %%
somme(4, 10)
# Out:
# -6

# %%
# Fonction qui calcule l'addition de deux nombres

# %% [markdown]
# **La fonction range()**
#
# Si vous avez besoin de créer sur une suite d’entiers, vous pouvez utiliser la fonction range(). Elle génère une suite arithmétique.

# %%
range(5)
# Out:
# range(0, 5)

# %%
list(range(5))
# Out:
# [0, 1, 2, 3, 4]

# %% [markdown]
# **La fonction len()**
#
# La fonction len() renvoie le nombre d’éléments. Par exemple :

# %%
a = list(range(7,10))
a
# Out:
# [7, 8, 9]

# %%
len(a)
# Out:
# 3

# %% [markdown]
# ### **5- Modules et importations**
#
# * Un module en Python est un fichier contenant des définitions et des instructions Python. Il peut inclure des variables, des fonctions...
#
# * L'utilisation de modules permet d'organiser le code de manière modulaire et de le réutiliser facilement.

# %% [markdown]
# **Importation de Modules :**
#
# On utilise l'instruction **import** pour importer un module dans un script Python. Voici quelques exemples :

# %%
# Exemple 1 : Importation d'un module entier
import math
print(math.sqrt(16))  # Utilisation de la fonction sqrt du module math
# Out:
# 4.0

# %%
# Exemple 2 : Importation avec un alias
import numpy as np
arr = np.array([1, 2, 3])
print(arr)

# %%
# Exemple 3 : Importation spécifique d'une fonction ou variable
from random import randint
print(randint(1, 100))  # Utilisation de la fonction randint directement
